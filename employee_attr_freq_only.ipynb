# %%
#importation des packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

employee_attrition = pd.read_csv(r"C:\Disque Perso 2023-10-20\DATA\Employee attrition\employee_attrition_dataset_10000.csv")

age_range = [20,25,30,35,40,45,50,55,60]
age_cat = ['[20-25[','[25-30[','[30-35[','[35-40[','[40-45[','[45-50[','[50-55[','[55-60[']
employee_attrition['Age_category'] = pd.cut(employee_attrition['Age'], bins=age_range, labels = age_cat, right=False,include_lowest=True)

attrition_filter = employee_attrition['Attrition']=='Yes'
attrition_leave = employee_attrition[attrition_filter]
attrition_leave
# Out:
#       Employee_ID  Age  Gender Marital_Status Department   Job_Role  \
# 2               3   34  Female        Married  Marketing    Manager
# 5               6   58    Male        Married    Finance  Executive
# 6               7   38    Male        Married      Sales  Executive
# 11             12   55  Female         Single    Finance    Analyst
# 14             15   22  Female       Divorced         IT    Analyst
# ...           ...  ...     ...            ...        ...        ...
# 9979         9980   39  Female         Single      Sales    Analyst
# 9980         9981   29    Male        Married         IT  Executive
# 9989         9990   40  Female         Single         HR  Assistant
# 9997         9998   23    Male       Divorced         IT    Manager
# 9999        10000   39  Female       Divorced    Finance  Executive
#
#       Job_Level  Monthly_Income  Hourly_Rate  Years_at_Company  ...  \
# 2             4           11485           65                 6  ...
# ...

# %%
sns.countplot(data=attrition_leave, x="Age_category")
plt.title("attrition frequency per age")
plt.show()

sns.catplot(data=attrition_leave, x="Overtime", kind='count')
plt.title("attrition frequency per overtimme")
plt.show()

# %%
sns.catplot(data=attrition_leave, x="Gender", kind='count')
plt.title("attrition frequency per Gender")
plt.show()

sns.catplot(data=attrition_leave, x="Marital_Status", kind='count')
plt.title("attrition frequency per Marital_Status")
plt.show()

sns.catplot(data=attrition_leave, x="Job_Role", kind='count')
plt.title("attrition frequency per Job_Role")
plt.show()

sns.catplot(data=attrition_leave, x="Job_Level", kind='count')
plt.title("attrition frequency per Job_Level")
plt.show()

sns.catplot(data=attrition_leave, x="Work_Life_Balance", kind='count')
plt.title("attrition frequency per Work_Life_Balance")
plt.show()

# %% [markdown]
# sns.catplot(data=attrition_leave, x="Job_Satisfaction", kind='count')
# plt.title("attrition frequency per Job_Satisfaction")
# plt.show()
#
# sns.catplot(data=attrition_leave, x="Relationship_with_Manager", kind='count')
# plt.title("attrition frequency per Relationship_with_Manager")
# plt.show()
#
# sns.catplot(data=attrition_leave, x="Job_Involvement", kind='count')
# plt.title("attrition frequency per Job_Involvement")
# plt.show()
#
# sns.catplot(data=attrition_leave, x="Number_of_Companies_Worked", kind='count')
# plt.title("attrition frequency per Number_of_Companies_Worked")
# plt.show()
#
# sns.catplot(data=attrition_leave, x="Work_Environment_Satisfaction", kind='count')
# plt.title("attrition frequency per Work_Environment_Satisfaction")
# plt.show()

# %%
#Among the categorical variables, we notice that some are more relevent when it comes to talk about employee attrition. This variables are : 
# Age, Job_level, Job_Role, Work_life_balance, Work_Environment_Satisfaction, Job_involvment

#Let's make deeper analyse for these variable

# %%
attrition_leave
# Out:
#       Employee_ID  Age  Gender Marital_Status Department   Job_Role  \
# 2               3   34  Female        Married  Marketing    Manager
# 5               6   58    Male        Married    Finance  Executive
# 6               7   38    Male        Married      Sales  Executive
# 11             12   55  Female         Single    Finance    Analyst
# 14             15   22  Female       Divorced         IT    Analyst
# ...           ...  ...     ...            ...        ...        ...
# 9979         9980   39  Female         Single      Sales    Analyst
# 9980         9981   29    Male        Married         IT  Executive
# 9989         9990   40  Female         Single         HR  Assistant
# 9997         9998   23    Male       Divorced         IT    Manager
# 9999        10000   39  Female       Divorced    Finance  Executive
#
#       Job_Level  Monthly_Income  Hourly_Rate  Years_at_Company  ...  \
# 2             4           11485           65                 6  ...
# ...

# %% [markdown]
# #PLAN
# #COMPARE : 1
# - attrition (yes non) vs average salary
# - attrition (yes non) vs project count
# - attrition (yes non) vs hourly rate
# - attrition (yes non) vs years at company
# - attrition (yes non) vs average hour worked per week
# - attrition (yes non) vs absenteism
# - attrition (yes non) vs distance from home
# using the 'employee_attrition' data

# %%
#Age vs Monthly_Income
sns.boxplot(data=employee_attrition, x='Attrition', y='Monthly_Income')
plt.clf()
sns.boxplot(data=employee_attrition, x='Attrition', y='Hourly_Rate')
plt.clf()
sns.boxplot(data=employee_attrition, x='Attrition', y='Years_at_Company')
plt.clf()
sns.boxplot(data=employee_attrition, x='Attrition', y='Project_Count')
plt.clf()
sns.boxplot(data=employee_attrition, x='Attrition', y='Average_Hours_Worked_Per_Week')
plt.clf()
sns.boxplot(data=employee_attrition, x='Attrition', y='Absenteeism')
plt.clf()

sns.boxplot(data=employee_attrition, x='Attrition', y='Distance_From_Home')
plt.show()




mean_hour_worked_attrition = employee_attrition[employee_attrition['Attrition']=='Yes']['Average_Hours_Worked_Per_Week'].mean()
mean_hour_worked_attrition
# Out:
# np.float64(44.43114672008012)

# %% [markdown]
# #PLAN NEXT
# #COMPARE : 2
# Compare these variables ' Age, 'Job_level', 'Job_Role, ''Work_life_balance', 'Job_satisfaction', 'Job_involvment' with others numerical variables
# using the 'employee_attrition' data
# and using the 'attrition_leave' data

# %%
#JOB ROLE vs revenue
sns.catplot(data=employee_attrition, x='Job_Role', y='Monthly_Income', kind='box', col='Attrition', order=['Manager','Executive','Analyst','Assistant'])

# %%
#JOB ROLE vs average hours worked per week
sns.catplot(data=employee_attrition, x='Job_Role', y='Average_Hours_Worked_Per_Week', kind='box', col='Attrition', order=['Manager','Executive','Analyst','Assistant'])

# %%
#JOB ROLE vs average hours worked per week vs Job_involvment
sns.catplot(data=employee_attrition, x= 'Department', y='Average_Hours_Worked_Per_Week', kind='box', col='Attrition')

# %%
#Compare these variables ' Age, 'Job_level', 'Job_Role, ''Work_life_balance', 'Job_satisfaction', 'Job_involvment' with others numerical variables
#JOB ROLE vs average hours worked per week vs Work_life_balance
sns.catplot(data=employee_attrition, x='Job_Role', y='Average_Hours_Worked_Per_Week', kind='box', col='Attrition', hue = 'Job_Satisfaction', order=['Manager','Executive','Analyst','Assistant'])

# %%
#Let's check if the absenteeism plays a role in the employee attrition
sns.relplot(data=attrition_leave, x='Absenteeism' , y='Distance_From_Home', kind='scatter' )
